# %%
import networkx as nx

# %%
G1, G2 = nx.Graph(), nx.Graph()

G1.add_edges_from([
    ('v1', 'v2'),
    ('v2', 'v3'),
    ('v2', 'v4'),
    ('v3', 'v4'),
    ('v3', 'v6'),
    ('v4', 'v5'),
])

# %%
nx.draw(G1)
